# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.sort_values(by=['total_bill', 'tip'],ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %%
tips.sort_values(by=['size','tip'],ascending=[False,True]).head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 153       24.55  2.00    Male     No   Sun  Dinner     4

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[3:7,:]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False

# %%
df.loc[:4,'pclass':'fare']
# Out:
#    pclass     sex   age  sibsp  parch     fare
# 0       3    male  22.0      1      0   7.2500
# 1       1  female  38.0      1      0  71.2833
# 2       3  female  26.0      0      0   7.9250
# 3       1  female  35.0      1      0  53.1000
# 4       3    male  35.0      0      0   8.0500

# %%
df.loc[2:10:2,['age','who']]
# Out:
#      age    who
# 2   26.0  woman
# 4   35.0    man
# 6   54.0    man
# 8   27.0  woman
# 10   4.0  child

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[df['age']>=30].sort_values(by='fare', ascending=False).head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 299         1       1  female  50.0      0      1  247.5208        C  First
# 716         1       1  female  38.0      0      0  227.5250        C  First
# 380         1       1  female  42.0      0      0  227.5250        C  First
# 779         1       1  female  43.0      0      1  211.3375        S  First
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 318         1       1  female  31.0      0      2  164.8667        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# ...

# %%
condition1 = (df['age']>=20) & (df['age']<40)
condition2 = (df['pclass'] == 1) | (df['pclass'] == 2)
df.loc[condition1 & condition2][['survived', 'pclass', 'age', 'fare']]
# Out:
#      survived  pclass   age     fare
# 1           1       1  38.0  71.2833
# 3           1       1  35.0  53.1000
# 20          0       2  35.0  26.0000
# 21          1       2  34.0  13.0000
# 23          1       1  28.0  35.5000
# ..        ...     ...   ...      ...
# 874         1       2  28.0  24.0000
# 880         1       2  25.0  26.0000
# 883         0       2  28.0  10.5000
# 886         0       2  27.0  13.0000
# 889         1       1  26.0  30.0000
#
# [185 rows x 4 columns]

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
temp1 = tips[(tips['day'] == 'Fri') | (tips['day'] == 'Sat')]
temp1[temp1['tip'] < 10][['total_bill', 'tip', 'smoker', 'time']].head(10)
# Out:
#     total_bill   tip smoker    time
# 19       20.65  3.35     No  Dinner
# 20       17.92  4.08     No  Dinner
# 21       20.29  2.75     No  Dinner
# 22       15.77  2.23     No  Dinner
# 23       39.42  7.58     No  Dinner
# 24       19.82  3.18     No  Dinner
# 25       17.81  2.34     No  Dinner
# 26       13.37  2.00     No  Dinner
# 27       12.69  2.00     No  Dinner
# 28       21.70  4.30     No  Dinner

# %%
temp1 = df[(df['fare'] >= 30) & (df['fare'] < 40)]
temp1[temp1['pclass'] == 1].shape[0]
# Out:
# 28

# %%
temp1[temp1['pclass'] == 1]['age'].count()
# Out:
# 21

# %%
temp1[temp1['pclass'] == 1]['age'].describe()['mean']
# Out:
# 44.095238095238095

# %%
diamond = sns.load_dataset('diamonds')
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond.describe()['depth']['min']
# Out:
# 43.0

# %%
# carat_mean = diamond.describe()['carat']['mean']
# carat_var = ((diamond['carat'].values - carat_mean) ** 2).sum() / (diamond['carat'].count() - 1)
# carat_var
diamond['carat'].agg(['mean','var'])
# Out:
# mean    0.797940
# var     0.224687
# Name: carat, dtype: float64

# %%
# diamond.describe()[['x','y']].loc['std']
# sum(diamond[['x','y']])
diamond[['x','y']].agg(['sum','std'])
# Out:
#                  x              y
# sum  309138.620000  309320.330000
# std       1.121761       1.142135

# %%
penguin = sns.load_dataset('penguins')
penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguin['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguin['island'].mode()
# Out:
# 0    Biscoe
# Name: island, dtype: object

# %%
penguin['body_mass_g'].quantile(0.1)
# Out:
# 3300.0

# %%
penguin['body_mass_g'].quantile(0.8)
# Out:
# 4950.0
